# %%
import os
import cv2
import numpy as np
import histomicstk as htk
import scipy as sp
import skimage.io
import skimage.measure
import skimage.color
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from PIL import Image
import time

from glob import glob
from os.path import expanduser, join, basename

plt.rcParams['figure.figsize'] = 15,15
plt.rcParams['image.cmap'] = 'gray'
titlesize = 24

# %%
# Reading in color default. Change to zero for grayscale
def read_image(filename,mode=1):
    try:
        img = cv2.imread(filename,mode)
    except e:
        raise e
    if img is None:
        print('Check your path. Not a file path. Probably a folder path.')
    return img

def write_image(filename,img):
    try:
        cv2.imwrite(filename,img)
    except e:
        raise e
        
def image_check(image_name):
    if image_name.split('.')[-1] not in ['jpg','jpeg','png']:
        return False
    return True
    
def cal_iou(img1, img2):
    intersection = np.sum(img1*img2)
    union = np.sum(img1 + img2) - intersection
    
    return intersection/union

# %%
def segment(image_path, ref_path, output_path, gt_path):
    
    #Constants:
    foreground_threshold = 180
    min_radius = 5
    max_radius = 100
    min_nucleus_area = 150
    
    #reading images
    imInput = skimage.io.imread(image_path)[:, :, :3]
    imReference = skimage.io.imread(ref_path)[:, :, :3]
    gt = skimage.io.imread(gt_path) #[:,:,0]

    # Get the mean and standard deviation of reference image in LAB colorspace
    meanRef, stdRef = htk.preprocessing.color_conversion.lab_mean_std(imReference)

    # Perform Reinhard Color Normalization on Input Image
    imNmzd = htk.preprocessing.color_normalization.reinhard(imInput,meanRef,stdRef)

    # Macenko PCA to get the stain vectors 
    I_0 = 255
    w_est = htk.preprocessing.color_deconvolution.rgb_separate_stains_macenko_pca(imNmzd,I_0=255)

    # Perform the deconvolution using the stain vectors
    deconv_result = htk.preprocessing.color_deconvolution.color_deconvolution(imInput, w_est,I_0)

    #stains = ['hematoxylin','eosin','null']
    #In this case we are taking eosin, that is why 1, else 0 in next line
    imNucleiStain = deconv_result.Stains[:,:,1]

    # Now we do segmentation based on a fixed intensity value.
    imFgndMask = sp.ndimage.morphology.binary_fill_holes(imNucleiStain<foreground_threshold)

    imLog = htk.filters.shape.clog(imNucleiStain, imFgndMask,\
                                   sigma_min=min_radius * np.sqrt(2),\
                                   sigma_max=max_radius * np.sqrt(2))

    # detect and segment nuclei using local maximum clustering
    local_max_search_radius = 10
    imNucleiSegMask1, Seeds, Max = htk.segmentation.nuclear.max_clustering(imLog[0], imFgndMask, local_max_search_radius)

    # filter out small objects
    imNucleiSegMask = htk.segmentation.label.area_open(imNucleiSegMask1, min_nucleus_area).astype(np.int)

    imNucleicompact = htk.segmentation.label.compact(imNucleiSegMask, compaction=3)
    k= (imNucleicompact==-1)
    imNucleicompact1=np.copy(k)
    # plt.rcParams['figure.figsize'] = 15,15    
    for ii in range(0,imNucleicompact.shape[0]):
        for jj in range(0,imNucleicompact.shape[1]):
            if imNucleicompact[ii,jj]>0:
                imNucleicompact1[ii,jj]=1

    imNucleicompact2 = skimage.measure.label(imNucleicompact1,connectivity = 1)
    # imInput2 = np.copy(imNmzd)
    # plt.rcParams['figure.figsize'] = 1, 1

    mask_generated = np.copy(imNucleicompact2)
    mask_generated[mask_generated>0] = 1
    gt[gt>0] = 1

    iou_cal = cal_iou(gt, mask_generated)
    
    mask_generated[mask_generated>0] = 255
    cv2.imwrite(os.path.join(output_path , image_path.split('/')[-1]), mask_generated)
    
    return iou_cal

# %%
image_path = "Input_Images/01_1.png"
ref_path = "BM_GRAZ_HE_0007_01.png"
output_path = "Output_Images/"
gt_path = "Ground_Truth/01_1.png"

iou = segment(image_path, ref_path, output_path, gt_path)

print(iou)
# Out:
# /home/satya/Vijay/histomics/HistomicsTK/histomicstk/preprocessing/color_conversion/rgb_to_sda.py:48: RuntimeWarning: divide by zero encountered in log
#   im_sda = -np.log(im_rgb/(1.*I_0)) * 255/np.log(I_0)
# 0.6879188144329897

# %%
iou_list = []
ref_path = "BM_GRAZ_HE_0007_01.png"

#For TNBC
# input_dir = "Input_Images"
# gt_dir = "Ground_Truth"
# inputs = glob(join(input_dir, '*.png'))
# gts = glob(join(gt_dir, '*.png'))


#For PSB
input_dir = "training/image/"
gt_dir = "training/gt/"
inputs = glob(join(input_dir, '*.tiff'))
inputs = sorted(inputs, key=lambda x: int(x.split('_')[0].split('/')[-1]))

gts = glob(join(gt_dir, '*.bmp'))
gts = sorted(gts, key=lambda x: int(x.split('_')[0].split('/')[-1]))

output_dir = "Output_Images"

start_time = time.time()
if len(inputs) == len(gts):
    for i in range(len(inputs)):
        print("Processing {} & {}".format(inputs[i], gts[i]))
        iou = segment(inputs[i], ref_path, output_dir, gts[i])
        iou_list.append(iou)
        print("IOU: {}".format(iou))
    print("Completed processing all images")    

print("----------Total Time Taken: {} minutes-----------".format((time.time()-start_time)/60))

# %%
# int(inputs[1].split('_')[0].split('/')[-1])
sorted(gts, key=lambda x: int(x.split('_')[0].split('/')[-1]))
# Out:
# ['training/gt/1_gt.bmp',
#  'training/gt/2_gt.bmp',
#  'training/gt/3_gt.bmp',
#  'training/gt/4_gt.bmp',
#  'training/gt/5_gt.bmp',
#  'training/gt/6_gt.bmp',
#  'training/gt/7_gt.bmp',
#  'training/gt/8_gt.bmp',
#  'training/gt/9_gt.bmp',
#  'training/gt/10_gt.bmp',
#  'training/gt/11_gt.bmp',
#  'training/gt/12_gt.bmp',
#  'training/gt/13_gt.bmp',
#  'training/gt/14_gt.bmp',
#  'training/gt/15_gt.bmp',
#  'training/gt/16_gt.bmp',
#  'training/gt/17_gt.bmp',
#  'training/gt/18_gt.bmp',
#  'training/gt/19_gt.bmp',
#  'training/gt/20_gt.bmp',
#  'training/gt/21_gt.bmp',
#  'training/gt/22_gt.bmp',
#  'training/gt/23_gt.bmp',
#  'training/gt/24_gt.bmp',
#  'training/gt/25_gt.bmp',
#  'training/gt/26_gt.bmp',
#  'training/gt/27_gt.bmp',
#  'training/gt/28_gt.bmp',
#  'training/gt/29_gt.bmp',
#  'training/gt/30_gt.bmp',
#  'training/gt/31_gt.bmp',
#  'training/gt/32_gt.bmp',
#  'training/gt/33_gt.bmp',
#  'training/gt/34_gt.bmp',
#  'training/gt/35_gt.bmp',
#  'training/gt/36_gt.bmp',
#  'training/gt/37_gt.bmp',
#  'training/gt/38_gt.bmp',
#  'training/gt/39_gt.bmp',
#  'training/gt/40_gt.bmp',
#  'training/gt/41_gt.bmp',
#  'training/gt/42_gt.bmp',
#  'training/gt/43_gt.bmp',
#  'training/gt/44_gt.bmp',
#  'training/gt/45_gt.bmp',
#  'training/gt/46_gt.bmp',
#  'training/gt/47_gt.bmp',
#  'training/gt/48_gt.bmp',
#  'training/gt/49_gt.bmp',
#  'training/gt/50_gt.bmp',
#  'training/gt/51_gt.bmp',
#  'training/gt/52_gt.bmp',
#  'training/gt/53_gt.bmp',
#  'training/gt/54_gt.bmp',
#  'training/gt/55_gt.bmp',
#  'training/gt/56_gt.bmp',
#  'training/gt/57_gt.bmp',
#  'training/gt/58_gt.bmp',
#  'training/gt/59_gt.bmp',
#  'training/gt/60_gt.bmp',
#  'training/gt/61_gt.bmp',
#  'training/gt/62_gt.bmp',
#  'training/gt/63_gt.bmp',
#  'training/gt/64_gt.bmp',
#  'training/gt/65_gt.bmp',
#  'training/gt/66_gt.bmp',
#  'training/gt/67_gt.bmp',
#  'training/gt/68_gt.bmp',
#  'training/gt/69_gt.bmp',
#  'training/gt/70_gt.bmp',
#  'training/gt/71_gt.bmp',
#  'training/gt/72_gt.bmp',
#  'training/gt/73_gt.bmp',
#  'training/gt/74_gt.bmp',
#  'training/gt/75_gt.bmp',
#  'training/gt/76_gt.bmp',
#  'training/gt/77_gt.bmp',
#  'training/gt/78_gt.bmp',
#  'training/gt/79_gt.bmp',
#  'training/gt/80_gt.bmp',
#  'training/gt/81_gt.bmp',
#  'training/gt/82_gt.bmp',
#  'training/gt/83_gt.bmp',
#  'training/gt/84_gt.bmp',
#  'training/gt/85_gt.bmp',
#  'training/gt/86_gt.bmp',
#  'training/gt/87_gt.bmp',
#  'training/gt/88_gt.bmp',
#  'training/gt/89_gt.bmp',
#  'training/gt/90_gt.bmp',
#  'training/gt/91_gt.bmp',
#  'training/gt/92_gt.bmp',
#  'training/gt/93_gt.bmp',
#  'training/gt/94_gt.bmp',
#  'training/gt/95_gt.bmp',
#  'training/gt/96_gt.bmp',
#  'training/gt/97_gt.bmp',
#  'training/gt/98_gt.bmp',
#  'training/gt/99_gt.bmp',
#  'training/gt/100_gt.bmp',
#  'training/gt/101_gt.bmp',
#  'training/gt/102_gt.bmp',
#  'training/gt/103_gt.bmp',
#  'training/gt/104_gt.bmp',
#  'training/gt/105_gt.bmp',
#  'training/gt/106_gt.bmp',
#  'training/gt/107_gt.bmp',
#  'training/gt/108_gt.bmp',
#  'training/gt/109_gt.bmp',
#  'training/gt/110_gt.bmp',
#  'training/gt/111_gt.bmp',
#  'training/gt/112_gt.bmp',
#  'training/gt/113_gt.bmp',
#  'training/gt/114_gt.bmp',
#  'training/gt/115_gt.bmp',
#  'training/gt/116_gt.bmp',
#  'training/gt/117_gt.bmp',
#  'training/gt/118_gt.bmp',
#  'training/gt/119_gt.bmp',
#  'training/gt/120_gt.bmp',
#  'training/gt/121_gt.bmp',
#  'training/gt/122_gt.bmp',
#  'training/gt/123_gt.bmp',
#  'training/gt/124_gt.bmp',
#  'training/gt/125_gt.bmp',
#  'training/gt/126_gt.bmp',
#  'training/gt/127_gt.bmp',
#  'training/gt/128_gt.bmp',
#  'training/gt/129_gt.bmp',
#  'training/gt/130_gt.bmp',
#  'training/gt/131_gt.bmp',
#  'training/gt/132_gt.bmp',
#  'training/gt/133_gt.bmp',
#  'training/gt/134_gt.bmp',
#  'training/gt/135_gt.bmp',
#  'training/gt/136_gt.bmp',
#  'training/gt/137_gt.bmp',
#  'training/gt/138_gt.bmp',
#  'training/gt/139_gt.bmp',
#  'training/gt/140_gt.bmp',
#  'training/gt/141_gt.bmp',
#  'training/gt/142_gt.bmp',
#  'training/gt/143_gt.bmp',
#  'training/gt/144_gt.bmp',
#  'training/gt/145_gt.bmp',
#  'training/gt/146_gt.bmp',
#  'training/gt/147_gt.bmp',
#  'training/gt/148_gt.bmp',
#  'training/gt/149_gt.bmp',
#  'training/gt/150_gt.bmp',
#  'training/gt/151_gt.bmp',
#  'training/gt/152_gt.bmp',
#  'training/gt/153_gt.bmp',
#  'training/gt/154_gt.bmp',
#  'training/gt/155_gt.bmp',
#  'training/gt/156_gt.bmp',
#  'training/gt/157_gt.bmp',
#  'training/gt/158_gt.bmp',
#  'training/gt/159_gt.bmp',
#  'training/gt/160_gt.bmp',
#  'training/gt/161_gt.bmp',
#  'training/gt/162_gt.bmp',
#  'training/gt/163_gt.bmp',
#  'training/gt/164_gt.bmp',
#  'training/gt/165_gt.bmp',
#  'training/gt/166_gt.bmp',
#  'training/gt/167_gt.bmp',
#  'training/gt/168_gt.bmp',
#  'training/gt/169_gt.bmp',
#  'training/gt/170_gt.bmp',
#  'training/gt/171_gt.bmp',
#  'training/gt/172_gt.bmp',
#  'training/gt/173_gt.bmp',
#  'training/gt/174_gt.bmp',
#  'training/gt/175_gt.bmp',
#  'training/gt/176_gt.bmp',
#  'training/gt/177_gt.bmp',
#  'training/gt/178_gt.bmp',
#  'training/gt/179_gt.bmp',
#  'training/gt/180_gt.bmp',
#  'training/gt/181_gt.bmp',
#  'training/gt/182_gt.bmp',
#  'training/gt/183_gt.bmp',
#  'training/gt/184_gt.bmp',
#  'training/gt/185_gt.bmp',
#  'training/gt/186_gt.bmp',
#  'training/gt/187_gt.bmp',
#  'training/gt/188_gt.bmp',
#  'training/gt/189_gt.bmp',
#  'training/gt/190_gt.bmp',
#  'training/gt/191_gt.bmp',
#  'training/gt/192_gt.bmp',
#  'training/gt/193_gt.bmp',
#  'training/gt/194_gt.bmp',
#  'training/gt/195_gt.bmp',
#  'training/gt/196_gt.bmp',
#  'training/gt/197_gt.bmp',
#  'training/gt/198_gt.bmp',
#  'training/gt/199_gt.bmp',
#  'training/gt/200_gt.bmp',
#  'training/gt/201_gt.bmp',
#  'training/gt/202_gt.bmp',
#  'training/gt/203_gt.bmp',
#  'training/gt/204_gt.bmp',
#  'training/gt/205_gt.bmp',
#  'training/gt/206_gt.bmp',
#  'training/gt/207_gt.bmp',
#  'training/gt/208_gt.bmp',
#  'training/gt/209_gt.bmp',
#  'training/gt/210_gt.bmp',
#  'training/gt/211_gt.bmp',
#  'training/gt/212_gt.bmp',
#  'training/gt/213_gt.bmp',
#  'training/gt/214_gt.bmp',
#  'training/gt/215_gt.bmp',
#  'training/gt/216_gt.bmp',
#  'training/gt/217_gt.bmp',
#  'training/gt/218_gt.bmp',
#  'training/gt/219_gt.bmp',
#  'training/gt/220_gt.bmp',
#  'training/gt/221_gt.bmp',
#  'training/gt/222_gt.bmp',
#  'training/gt/223_gt.bmp',
#  'training/gt/224_gt.bmp',
#  'training/gt/225_gt.bmp',
#  'training/gt/226_gt.bmp',
#  'training/gt/227_gt.bmp',
#  'training/gt/228_gt.bmp',
#  'training/gt/229_gt.bmp',
#  'training/gt/230_gt.bmp',
#  'training/gt/231_gt.bmp',
#  'training/gt/232_gt.bmp',
#  'training/gt/233_gt.bmp',
#  'training/gt/234_gt.bmp',
#  'training/gt/235_gt.bmp',
#  'training/gt/236_gt.bmp',
#  'training/gt/237_gt.bmp',
#  'training/gt/238_gt.bmp',
#  'training/gt/239_gt.bmp',
#  'training/gt/240_gt.bmp',
#  'training/gt/241_gt.bmp',
#  'training/gt/242_gt.bmp',
#  'training/gt/243_gt.bmp',
#  'training/gt/244_gt.bmp',
#  'training/gt/245_gt.bmp',
#  'training/gt/246_gt.bmp',
#  'training/gt/247_gt.bmp',
#  'training/gt/248_gt.bmp',
#  'training/gt/249_gt.bmp',
#  'training/gt/250_gt.bmp',
#  'training/gt/251_gt.bmp',
#  'training/gt/252_gt.bmp',
#  'training/gt/253_gt.bmp',
#  'training/gt/254_gt.bmp',
#  'training/gt/255_gt.bmp',
#  'training/gt/256_gt.bmp',
#  'training/gt/257_gt.bmp',
#  'training/gt/258_gt.bmp',
#  'training/gt/259_gt.bmp',
#  'training/gt/260_gt.bmp',
#  'training/gt/261_gt.bmp',
#  'training/gt/262_gt.bmp',
#  'training/gt/263_gt.bmp',
#  'training/gt/264_gt.bmp',
#  'training/gt/265_gt.bmp',
#  'training/gt/266_gt.bmp',
#  'training/gt/267_gt.bmp',
#  'training/gt/268_gt.bmp',
#  'training/gt/269_gt.bmp',
#  'training/gt/270_gt.bmp',
#  'training/gt/271_gt.bmp',
#  'training/gt/272_gt.bmp',
#  'training/gt/273_gt.bmp',
#  'training/gt/274_gt.bmp',
#  'training/gt/275_gt.bmp',
#  'training/gt/276_gt.bmp',
#  'training/gt/277_gt.bmp',
#  'training/gt/278_gt.bmp',
#  'training/gt/279_gt.bmp',
#  'training/gt/280_gt.bmp',
#  'training/gt/281_gt.bmp',
#  'training/gt/282_gt.bmp',
#  'training/gt/283_gt.bmp',
#  'training/gt/284_gt.bmp',
#  'training/gt/285_gt.bmp',
#  'training/gt/286_gt.bmp',
#  'training/gt/287_gt.bmp',
#  'training/gt/288_gt.bmp',
#  'training/gt/289_gt.bmp',
#  'training/gt/290_gt.bmp',
#  'training/gt/291_gt.bmp',
#  'training/gt/292_gt.bmp',
#  'training/gt/293_gt.bmp',
#  'training/gt/294_gt.bmp',
#  'training/gt/295_gt.bmp',
#  'training/gt/296_gt.bmp',
#  'training/gt/297_gt.bmp',
#  'training/gt/298_gt.bmp',
#  'training/gt/299_gt.bmp',
#  'training/gt/300_gt.bmp',
#  'training/gt/301_gt.bmp',
#  'training/gt/302_gt.bmp',
#  'training/gt/303_gt.bmp',
#  'training/gt/304_gt.bmp',
#  'training/gt/305_gt.bmp',
#  'training/gt/306_gt.bmp',
#  'training/gt/307_gt.bmp',
#  'training/gt/308_gt.bmp',
#  'training/gt/309_gt.bmp',
#  'training/gt/310_gt.bmp',
#  'training/gt/311_gt.bmp',
#  'training/gt/312_gt.bmp',
#  'training/gt/313_gt.bmp',
#  'training/gt/314_gt.bmp',
#  'training/gt/315_gt.bmp',
#  'training/gt/316_gt.bmp',
#  'training/gt/317_gt.bmp',
#  'training/gt/318_gt.bmp',
#  'training/gt/319_gt.bmp',
#  'training/gt/320_gt.bmp',
#  'training/gt/321_gt.bmp',
#  'training/gt/322_gt.bmp',
#  'training/gt/323_gt.bmp',
#  'training/gt/324_gt.bmp',
#  'training/gt/325_gt.bmp',
#  'training/gt/326_gt.bmp',
#  'training/gt/327_gt.bmp',
#  'training/gt/328_gt.bmp',
#  'training/gt/329_gt.bmp',
#  'training/gt/330_gt.bmp',
#  'training/gt/331_gt.bmp',
#  'training/gt/332_gt.bmp',
#  'training/gt/333_gt.bmp',
#  'training/gt/334_gt.bmp',
#  'training/gt/335_gt.bmp',
#  'training/gt/336_gt.bmp',
#  'training/gt/337_gt.bmp',
#  'training/gt/338_gt.bmp',
#  'training/gt/339_gt.bmp',
#  'training/gt/340_gt.bmp',
#  'training/gt/341_gt.bmp',
#  'training/gt/342_gt.bmp',
#  'training/gt/343_gt.bmp',
#  'training/gt/344_gt.bmp',
#  'training/gt/345_gt.bmp',
#  'training/gt/346_gt.bmp',
#  'training/gt/347_gt.bmp',
#  'training/gt/348_gt.bmp',
#  'training/gt/349_gt.bmp',
#  'training/gt/350_gt.bmp',
#  'training/gt/351_gt.bmp',
#  'training/gt/352_gt.bmp',
#  'training/gt/353_gt.bmp',
#  'training/gt/354_gt.bmp',
#  'training/gt/355_gt.bmp',
#  'training/gt/356_gt.bmp',
#  'training/gt/357_gt.bmp',
#  'training/gt/358_gt.bmp',
#  'training/gt/359_gt.bmp',
#  'training/gt/360_gt.bmp',
#  'training/gt/361_gt.bmp',
#  'training/gt/362_gt.bmp',
#  'training/gt/363_gt.bmp',
#  'training/gt/364_gt.bmp',
#  'training/gt/365_gt.bmp',
#  'training/gt/366_gt.bmp',
#  'training/gt/367_gt.bmp',
#  'training/gt/368_gt.bmp',
#  'training/gt/369_gt.bmp',
#  'training/gt/370_gt.bmp',
#  'training/gt/371_gt.bmp',
#  'training/gt/372_gt.bmp',
#  'training/gt/373_gt.bmp',
#  'training/gt/374_gt.bmp',
#  'training/gt/375_gt.bmp',
#  'training/gt/376_gt.bmp',
#  'training/gt/377_gt.bmp',
#  'training/gt/378_gt.bmp',
#  'training/gt/379_gt.bmp',
#  'training/gt/380_gt.bmp',
#  'training/gt/381_gt.bmp',
#  'training/gt/382_gt.bmp',
#  'training/gt/383_gt.bmp',
#  'training/gt/384_gt.bmp',
#  'training/gt/385_gt.bmp',
#  'training/gt/386_gt.bmp',
#  'training/gt/387_gt.bmp',
#  'training/gt/388_gt.bmp',
#  'training/gt/389_gt.bmp',
#  'training/gt/390_gt.bmp',
#  'training/gt/391_gt.bmp',
#  'training/gt/392_gt.bmp',
#  'training/gt/393_gt.bmp',
#  'training/gt/394_gt.bmp',
#  'training/gt/395_gt.bmp',
#  'training/gt/396_gt.bmp',
#  'training/gt/397_gt.bmp',
#  'training/gt/398_gt.bmp',
#  'training/gt/399_gt.bmp',
#  'training/gt/400_gt.bmp',
#  'training/gt/401_gt.bmp',
#  'training/gt/402_gt.bmp',
#  'training/gt/403_gt.bmp',
#  'training/gt/404_gt.bmp',
#  'training/gt/405_gt.bmp',
#  'training/gt/406_gt.bmp',
#  'training/gt/407_gt.bmp',
#  'training/gt/408_gt.bmp',
#  'training/gt/409_gt.bmp',
#  'training/gt/410_gt.bmp',
#  'training/gt/411_gt.bmp',
#  'training/gt/412_gt.bmp',
#  'training/gt/413_gt.bmp',
#  'training/gt/414_gt.bmp',
#  'training/gt/415_gt.bmp',
#  'training/gt/416_gt.bmp',
#  'training/gt/417_gt.bmp',
#  'training/gt/418_gt.bmp',
#  'training/gt/419_gt.bmp',
#  'training/gt/420_gt.bmp',
#  'training/gt/421_gt.bmp',
#  'training/gt/422_gt.bmp',
#  'training/gt/423_gt.bmp',
#  'training/gt/424_gt.bmp',
#  'training/gt/425_gt.bmp',
#  'training/gt/426_gt.bmp',
#  'training/gt/427_gt.bmp',
#  'training/gt/428_gt.bmp',
#  'training/gt/429_gt.bmp',
#  'training/gt/430_gt.bmp',
#  'training/gt/431_gt.bmp',
#  'training/gt/432_gt.bmp',
#  'training/gt/433_gt.bmp',
#  'training/gt/434_gt.bmp',
#  'training/gt/435_gt.bmp',
#  'training/gt/436_gt.bmp',
#  'training/gt/437_gt.bmp',
#  'training/gt/438_gt.bmp',
#  'training/gt/439_gt.bmp',
#  'training/gt/440_gt.bmp',
#  'training/gt/441_gt.bmp',
#  'training/gt/442_gt.bmp',
#  'training/gt/443_gt.bmp',
#  'training/gt/444_gt.bmp',
#  'training/gt/445_gt.bmp',
#  'training/gt/446_gt.bmp',
#  'training/gt/447_gt.bmp',
#  'training/gt/448_gt.bmp',
#  'training/gt/449_gt.bmp',
#  'training/gt/450_gt.bmp',
#  'training/gt/451_gt.bmp',
#  'training/gt/452_gt.bmp',
#  'training/gt/453_gt.bmp',
#  'training/gt/454_gt.bmp',
#  'training/gt/455_gt.bmp',
#  'training/gt/456_gt.bmp',
#  'training/gt/457_gt.bmp',
#  'training/gt/458_gt.bmp',
#  'training/gt/459_gt.bmp',
#  'training/gt/460_gt.bmp',
#  'training/gt/461_gt.bmp',
#  'training/gt/462_gt.bmp',
#  'training/gt/463_gt.bmp',
#  'training/gt/464_gt.bmp',
#  'training/gt/465_gt.bmp',
#  'training/gt/466_gt.bmp',
#  'training/gt/467_gt.bmp',
#  'training/gt/468_gt.bmp',
#  'training/gt/469_gt.bmp',
#  'training/gt/470_gt.bmp',
#  'training/gt/471_gt.bmp',
#  'training/gt/472_gt.bmp',
#  'training/gt/473_gt.bmp',
#  'training/gt/474_gt.bmp',
#  'training/gt/475_gt.bmp',
#  'training/gt/476_gt.bmp',
#  'training/gt/477_gt.bmp',
#  'training/gt/478_gt.bmp',
#  'training/gt/479_gt.bmp',
#  'training/gt/480_gt.bmp',
#  'training/gt/481_gt.bmp',
#  'training/gt/482_gt.bmp',
#  'training/gt/483_gt.bmp',
#  'training/gt/484_gt.bmp',
#  'training/gt/485_gt.bmp',
#  'training/gt/486_gt.bmp',
#  'training/gt/487_gt.bmp',
#  'training/gt/488_gt.bmp',
#  'training/gt/489_gt.bmp',
#  'training/gt/490_gt.bmp',
#  'training/gt/491_gt.bmp',
#  'training/gt/492_gt.bmp',
#  'training/gt/493_gt.bmp',
#  'training/gt/494_gt.bmp',
#  'training/gt/495_gt.bmp',
#  'training/gt/496_gt.bmp',
#  'training/gt/497_gt.bmp',
#  'training/gt/498_gt.bmp',
#  'training/gt/499_gt.bmp',
#  'training/gt/500_gt.bmp',
#  'training/gt/501_gt.bmp',
#  'training/gt/502_gt.bmp',
#  'training/gt/503_gt.bmp',
#  'training/gt/504_gt.bmp',
#  'training/gt/505_gt.bmp',
#  'training/gt/506_gt.bmp',
#  'training/gt/507_gt.bmp',
#  'training/gt/508_gt.bmp',
#  'training/gt/509_gt.bmp',
#  'training/gt/510_gt.bmp',
#  'training/gt/511_gt.bmp',
#  'training/gt/512_gt.bmp',
#  'training/gt/513_gt.bmp',
#  'training/gt/514_gt.bmp',
#  'training/gt/515_gt.bmp',
#  'training/gt/516_gt.bmp',
#  'training/gt/517_gt.bmp',
#  'training/gt/518_gt.bmp',
#  'training/gt/519_gt.bmp',
#  'training/gt/520_gt.bmp',
#  'training/gt/521_gt.bmp',
#  'training/gt/522_gt.bmp',
#  'training/gt/523_gt.bmp',
#  'training/gt/524_gt.bmp',
#  'training/gt/525_gt.bmp',
#  'training/gt/526_gt.bmp',
#  'training/gt/527_gt.bmp',
#  'training/gt/528_gt.bmp',
#  'training/gt/529_gt.bmp',
#  'training/gt/530_gt.bmp',
#  'training/gt/531_gt.bmp',
#  'training/gt/532_gt.bmp',
#  'training/gt/533_gt.bmp',
#  'training/gt/534_gt.bmp',
#  'training/gt/535_gt.bmp',
#  'training/gt/536_gt.bmp',
#  'training/gt/537_gt.bmp',
#  'training/gt/538_gt.bmp',
#  'training/gt/539_gt.bmp',
#  'training/gt/540_gt.bmp',
#  'training/gt/541_gt.bmp',
#  'training/gt/542_gt.bmp',
#  'training/gt/543_gt.bmp',
#  'training/gt/544_gt.bmp',
#  'training/gt/545_gt.bmp',
#  'training/gt/546_gt.bmp',
#  'training/gt/547_gt.bmp',
#  'training/gt/548_gt.bmp',
#  'training/gt/549_gt.bmp',
#  'training/gt/550_gt.bmp',
#  'training/gt/551_gt.bmp',
#  'training/gt/552_gt.bmp',
#  'training/gt/553_gt.bmp',
#  'training/gt/554_gt.bmp',
#  'training/gt/555_gt.bmp',
#  'training/gt/556_gt.bmp',
#  'training/gt/557_gt.bmp',
#  'training/gt/558_gt.bmp',
#  'training/gt/559_gt.bmp',
#  'training/gt/560_gt.bmp',
#  'training/gt/561_gt.bmp',
#  'training/gt/562_gt.bmp',
#  'training/gt/563_gt.bmp',
#  'training/gt/564_gt.bmp',
#  'training/gt/565_gt.bmp',
#  'training/gt/566_gt.bmp',
#  'training/gt/567_gt.bmp',
#  'training/gt/568_gt.bmp',
#  'training/gt/569_gt.bmp',
#  'training/gt/570_gt.bmp',
#  'training/gt/571_gt.bmp',
#  'training/gt/572_gt.bmp',
#  'training/gt/573_gt.bmp',
#  'training/gt/574_gt.bmp',
#  'training/gt/575_gt.bmp',
#  'training/gt/576_gt.bmp',
#  'training/gt/577_gt.bmp',
#  'training/gt/578_gt.bmp',
#  'training/gt/579_gt.bmp',
#  'training/gt/580_gt.bmp',
#  'training/gt/581_gt.bmp',
#  'training/gt/582_gt.bmp',
#  'training/gt/583_gt.bmp',
#  'training/gt/584_gt.bmp',
#  'training/gt/585_gt.bmp',
#  'training/gt/586_gt.bmp',
#  'training/gt/587_gt.bmp',
#  'training/gt/588_gt.bmp',
#  'training/gt/589_gt.bmp',
#  'training/gt/590_gt.bmp',
#  'training/gt/591_gt.bmp',
#  'training/gt/592_gt.bmp',
#  'training/gt/593_gt.bmp',
#  'training/gt/594_gt.bmp',
#  'training/gt/595_gt.bmp',
#  'training/gt/596_gt.bmp',
#  'training/gt/597_gt.bmp',
#  'training/gt/598_gt.bmp',
#  'training/gt/599_gt.bmp',
#  'training/gt/600_gt.bmp',
#  'training/gt/601_gt.bmp',
#  'training/gt/602_gt.bmp',
#  'training/gt/603_gt.bmp',
#  'training/gt/604_gt.bmp',
#  'training/gt/605_gt.bmp',
#  'training/gt/606_gt.bmp',
#  'training/gt/607_gt.bmp',
#  'training/gt/608_gt.bmp',
#  'training/gt/609_gt.bmp',
#  'training/gt/610_gt.bmp',
#  'training/gt/611_gt.bmp',
#  'training/gt/612_gt.bmp',
#  'training/gt/613_gt.bmp',
#  'training/gt/614_gt.bmp',
#  'training/gt/615_gt.bmp',
#  'training/gt/616_gt.bmp',
#  'training/gt/617_gt.bmp',
#  'training/gt/618_gt.bmp',
#  'training/gt/619_gt.bmp',
#  'training/gt/620_gt.bmp',
#  'training/gt/621_gt.bmp',
#  'training/gt/622_gt.bmp',
#  'training/gt/623_gt.bmp',
#  'training/gt/624_gt.bmp',
#  'training/gt/625_gt.bmp',
#  'training/gt/626_gt.bmp',
#  'training/gt/627_gt.bmp',
#  'training/gt/628_gt.bmp',
#  'training/gt/629_gt.bmp',
#  'training/gt/630_gt.bmp',
#  'training/gt/631_gt.bmp',
#  'training/gt/632_gt.bmp',
#  'training/gt/633_gt.bmp',
#  'training/gt/634_gt.bmp',
#  'training/gt/635_gt.bmp',
#  'training/gt/636_gt.bmp',
#  'training/gt/637_gt.bmp',
#  'training/gt/638_gt.bmp',
#  'training/gt/639_gt.bmp',
#  'training/gt/640_gt.bmp',
#  'training/gt/641_gt.bmp',
#  'training/gt/642_gt.bmp',
#  'training/gt/643_gt.bmp',
#  'training/gt/644_gt.bmp',
#  'training/gt/645_gt.bmp',
#  'training/gt/646_gt.bmp']

# %%
im = skimage.io.imread("Output_Images/01_1.png")
plt.figure(figsize=(5,5))
plt.imshow(im)
plt.title('Output Image')
plt.show()

# %%
np.mean(np.array(iou_list))
# Out:
# 0.4902656852400685

# %%
len(iou_list)
# Out:
# 50

# %%
image_path = "training/image/52_sample.tiff"
ref_path = "BM_GRAZ_HE_0007_01.png"
output_path = "Output_Images/"
gt_path = "training/gt/52_gt.bmp"

iou = segment(image_path, ref_path, output_path, gt_path)

print(iou)
# Out:
# 0.4855272340566947
