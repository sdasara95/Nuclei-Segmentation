# %%
import os
import cv2
import numpy as np
import histomicstk as htk
import scipy as sp
import skimage.io
import skimage.measure
import skimage.color
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from PIL import Image
import time

from glob import glob
from os.path import expanduser, join, basename

plt.rcParams['figure.figsize'] = 15,15
plt.rcParams['image.cmap'] = 'gray'
titlesize = 24

# %%
# Reading in color default. Change to zero for grayscale
def read_image(filename,mode=1):
    try:
        img = cv2.imread(filename,mode)
    except e:
        raise e
    if img is None:
        print('Check your path. Not a file path. Probably a folder path.')
    return img

def write_image(filename,img):
    try:
        cv2.imwrite(filename,img)
    except e:
        raise e
        
def image_check(image_name):
    if image_name.split('.')[-1] not in ['jpg','jpeg','png']:
        return False
    return True
    
def cal_iou(img1, img2):
    intersection = np.sum(img1*img2)
    union = np.sum(img1 + img2) - intersection
    
    return intersection/union

# %%
def segment(image_path, ref_path, output_path, gt_path):
    
    #Constants:
    foreground_threshold = 180
    min_radius = 5
    max_radius = 100
    min_nucleus_area = 150
    
    #reading images
    imInput = skimage.io.imread(image_path)[:, :, :3]
    imReference = skimage.io.imread(ref_path)[:, :, :3]
    gt = skimage.io.imread(gt_path) #[:,:,0]

    # Get the mean and standard deviation of reference image in LAB colorspace
    meanRef, stdRef = htk.preprocessing.color_conversion.lab_mean_std(imReference)

    # Perform Reinhard Color Normalization on Input Image
    imNmzd = htk.preprocessing.color_normalization.reinhard(imInput,meanRef,stdRef)

    # Macenko PCA to get the stain vectors 
    I_0 = 255
    w_est = htk.preprocessing.color_deconvolution.rgb_separate_stains_macenko_pca(imNmzd,I_0=255)

    # Perform the deconvolution using the stain vectors
    deconv_result = htk.preprocessing.color_deconvolution.color_deconvolution(imInput, w_est,I_0)

    #stains = ['hematoxylin','eosin','null']
    #In this case we are taking eosin, that is why 1, else 0 in next line
    imNucleiStain = deconv_result.Stains[:,:,1]

    # Now we do segmentation based on a fixed intensity value.
    imFgndMask = sp.ndimage.morphology.binary_fill_holes(imNucleiStain<foreground_threshold)

    imLog = htk.filters.shape.clog(imNucleiStain, imFgndMask,\
                                   sigma_min=min_radius * np.sqrt(2),\
                                   sigma_max=max_radius * np.sqrt(2))

    # detect and segment nuclei using local maximum clustering
    local_max_search_radius = 10
    imNucleiSegMask1, Seeds, Max = htk.segmentation.nuclear.max_clustering(imLog[0], imFgndMask, local_max_search_radius)

    # filter out small objects
    imNucleiSegMask = htk.segmentation.label.area_open(imNucleiSegMask1, min_nucleus_area).astype(np.int)

    imNucleicompact = htk.segmentation.label.compact(imNucleiSegMask, compaction=3)
    k= (imNucleicompact==-1)
    imNucleicompact1=np.copy(k)
    # plt.rcParams['figure.figsize'] = 15,15    
    for ii in range(0,imNucleicompact.shape[0]):
        for jj in range(0,imNucleicompact.shape[1]):
            if imNucleicompact[ii,jj]>0:
                imNucleicompact1[ii,jj]=1

    imNucleicompact2 = skimage.measure.label(imNucleicompact1,connectivity = 1)
    # imInput2 = np.copy(imNmzd)
    # plt.rcParams['figure.figsize'] = 1, 1

    mask_generated = np.copy(imNucleicompact2)
    mask_generated[mask_generated>0] = 1
    gt[gt>0] = 1

    iou_cal = cal_iou(gt, mask_generated)
    
    mask_generated[mask_generated>0] = 255
    cv2.imwrite(os.path.join(output_path , image_path.split('/')[-1]), mask_generated)
    
    return iou_cal

# %%
image_path = "Input_Images/01_1.png"
ref_path = "BM_GRAZ_HE_0007_01.png"
output_path = "Output_Images/"
gt_path = "Ground_Truth/01_1.png"

iou = segment(image_path, ref_path, output_path, gt_path)

print(iou)
# Out:
# /home/satya/Vijay/histomics/HistomicsTK/histomicstk/preprocessing/color_conversion/rgb_to_sda.py:48: RuntimeWarning: divide by zero encountered in log
#   im_sda = -np.log(im_rgb/(1.*I_0)) * 255/np.log(I_0)
# 0.6879188144329897

# %%
iou_list = []
ref_path = "BM_GRAZ_HE_0007_01.png"

#For TNBC
# input_dir = "Input_Images"
# gt_dir = "Ground_Truth"
# inputs = glob(join(input_dir, '*.png'))
# gts = glob(join(gt_dir, '*.png'))


#For PSB
input_dir = "test/image/"
gt_dir = "test/gt/"
inputs = glob(join(input_dir, '*.tiff'))
inputs = sorted(inputs, key=lambda x: int(x.split('_')[0].split('/')[-1]))

gts = glob(join(gt_dir, '*.bmp'))
gts = sorted(gts, key=lambda x: int(x.split('_')[0].split('/')[-1]))

output_dir = "Output_Images/psb_test_images"

start_time = time.time()
if len(inputs) == len(gts):
    for i in range(len(inputs)):
        print("Processing {} & {}".format(inputs[i], gts[i]))
        iou = segment(inputs[i], ref_path, output_dir, gts[i])
        iou_list.append(iou)
        print("IOU: {}".format(iou))
    print("Completed processing all images")    

print("----------Total Time Taken: {} minutes-----------".format((time.time()-start_time)/60))
# Out:
# Processing test/image/1_sample.tiff & test/gt/1_gt.bmp
# IOU: 0.5435365509455264
# Processing test/image/2_sample.tiff & test/gt/2_gt.bmp
# IOU: 0.6301175382989963
# Processing test/image/3_sample.tiff & test/gt/3_gt.bmp
# IOU: 0.5898324232724534
# Processing test/image/4_sample.tiff & test/gt/4_gt.bmp
# IOU: 0.0
# Processing test/image/5_sample.tiff & test/gt/5_gt.bmp
# IOU: 0.5128948681989969
# Processing test/image/6_sample.tiff & test/gt/6_gt.bmp
# IOU: 0.3986682369994564
# Processing test/image/7_sample.tiff & test/gt/7_gt.bmp
# IOU: 0.5655387494152503
# Processing test/image/8_sample.tiff & test/gt/8_gt.bmp
# IOU: 0.5415502675776649
# Processing test/image/9_sample.tiff & test/gt/9_gt.bmp
# IOU: 0.3950743836408558
# Processing test/image/10_sample.tiff & test/gt/10_gt.bmp
# IOU: 0.3465556610827086
# Processing test/image/11_sample.tiff & test/gt/11_gt.bmp
# IOU: 0.09921761849317014
# Processing test/image/12_sample.tiff & test/gt/12_gt.bmp
# IOU: 0.1588498084397173
# Processing test/image/13_sample.tiff & test/gt/13_gt.bmp
# IOU: 0.38778072653597007
# Processing test/image/14_sample.tiff & test/gt/14_gt.bmp
# IOU: 0.3294751065091205
# Processing test/image/15_sample.tiff & test/gt/15_gt.bmp
# IOU: 0.18901184843389512
# Processing test/image/16_sample.tiff & test/gt/16_gt.bmp
# IOU: 0.3630686321128547
# Processing test/image/17_sample.tiff & test/gt/17_gt.bmp
# IOU: 0.32368272310494256
# Processing test/image/18_sample.tiff & test/gt/18_gt.bmp
# IOU: 0.1500968885654569
# Processing test/image/19_sample.tiff & test/gt/19_gt.bmp
# IOU: 0.30138162583614553
# Processing test/image/20_sample.tiff & test/gt/20_gt.bmp
# IOU: 0.3879661471671423
# Processing test/image/21_sample.tiff & test/gt/21_gt.bmp
# IOU: 0.4358521724275383
# Processing test/image/22_sample.tiff & test/gt/22_gt.bmp
# IOU: 0.33179507018901294
# Processing test/image/23_sample.tiff & test/gt/23_gt.bmp
# IOU: 0.5573272304344564
# Processing test/image/24_sample.tiff & test/gt/24_gt.bmp
# IOU: 0.5294946866189547
# Processing test/image/25_sample.tiff & test/gt/25_gt.bmp
# IOU: 0.4349729675942817
# Processing test/image/26_sample.tiff & test/gt/26_gt.bmp
# IOU: 0.6049519827529888
# Processing test/image/27_sample.tiff & test/gt/27_gt.bmp
# IOU: 0.4003406017297225
# Processing test/image/28_sample.tiff & test/gt/28_gt.bmp
# IOU: 0.4370848409569585
# Processing test/image/29_sample.tiff & test/gt/29_gt.bmp
# IOU: 0.5570288520564763
# Processing test/image/30_sample.tiff & test/gt/30_gt.bmp
# IOU: 0.043460221968675446
# Processing test/image/31_sample.tiff & test/gt/31_gt.bmp
# IOU: 0.46288061373434264
# Processing test/image/32_sample.tiff & test/gt/32_gt.bmp
# IOU: 0.190287375372925
# Processing test/image/33_sample.tiff & test/gt/33_gt.bmp
# IOU: 0.29516366113361775
# Processing test/image/34_sample.tiff & test/gt/34_gt.bmp
# IOU: 0.5201424384099222
# Processing test/image/35_sample.tiff & test/gt/35_gt.bmp
# IOU: 0.5589563999299597
# Processing test/image/36_sample.tiff & test/gt/36_gt.bmp
# IOU: 0.2712212577032668
# Processing test/image/37_sample.tiff & test/gt/37_gt.bmp
# IOU: 0.3306937610993042
# Processing test/image/38_sample.tiff & test/gt/38_gt.bmp
# IOU: 0.5177609748136865
# Processing test/image/39_sample.tiff & test/gt/39_gt.bmp
# IOU: 0.5679916905283252
# Processing test/image/40_sample.tiff & test/gt/40_gt.bmp
# IOU: 0.5338095238095238
# Processing test/image/41_sample.tiff & test/gt/41_gt.bmp
# IOU: 0.4703210694698355
# Processing test/image/42_sample.tiff & test/gt/42_gt.bmp
# IOU: 0.0
# Processing test/image/43_sample.tiff & test/gt/43_gt.bmp
# IOU: 0.5270156881690355
# Processing test/image/44_sample.tiff & test/gt/44_gt.bmp
# IOU: 0.4536149825783972
# Processing test/image/45_sample.tiff & test/gt/45_gt.bmp
# IOU: 0.4241865546792311
# Processing test/image/46_sample.tiff & test/gt/46_gt.bmp
# IOU: 0.07474449585600244
# Processing test/image/47_sample.tiff & test/gt/47_gt.bmp
# IOU: 0.020557029177718834
# Processing test/image/48_sample.tiff & test/gt/48_gt.bmp
# IOU: 0.3378506351435196
# Processing test/image/49_sample.tiff & test/gt/49_gt.bmp
# IOU: 0.49088669950738917
# Processing test/image/50_sample.tiff & test/gt/50_gt.bmp
# IOU: 0.5247805496063467
# Processing test/image/51_sample.tiff & test/gt/51_gt.bmp
# IOU: 0.35957428348324033
# Processing test/image/52_sample.tiff & test/gt/52_gt.bmp
# IOU: 0.39199921368193436
# Processing test/image/53_sample.tiff & test/gt/53_gt.bmp
# IOU: 0.4756820412168793
# Processing test/image/54_sample.tiff & test/gt/54_gt.bmp
# IOU: 0.5524280999528525
# Processing test/image/55_sample.tiff & test/gt/55_gt.bmp
# IOU: 0.37812628594943076
# Processing test/image/56_sample.tiff & test/gt/56_gt.bmp
# IOU: 0.4430384645151304
# Processing test/image/57_sample.tiff & test/gt/57_gt.bmp
# IOU: 0.3541986348484047
# Processing test/image/58_sample.tiff & test/gt/58_gt.bmp
# IOU: 0.5046534984934717
# Processing test/image/59_sample.tiff & test/gt/59_gt.bmp
# IOU: 0.5736377025036818
# Processing test/image/60_sample.tiff & test/gt/60_gt.bmp
# IOU: 0.0
# Processing test/image/61_sample.tiff & test/gt/61_gt.bmp
# IOU: 0.4755273321449792
# Processing test/image/62_sample.tiff & test/gt/62_gt.bmp
# IOU: 0.54239413842041
# Processing test/image/63_sample.tiff & test/gt/63_gt.bmp
# IOU: 0.5718857705563761
# Processing test/image/64_sample.tiff & test/gt/64_gt.bmp
# IOU: 0.5608576414859138
# Processing test/image/65_sample.tiff & test/gt/65_gt.bmp
# IOU: 0.4166666666666667
# Processing test/image/66_sample.tiff & test/gt/66_gt.bmp
# IOU: 0.5000137760022042
# Processing test/image/67_sample.tiff & test/gt/67_gt.bmp
# IOU: 0.41847306929238004
# Processing test/image/68_sample.tiff & test/gt/68_gt.bmp
# IOU: 0.5260157583239534
# Processing test/image/69_sample.tiff & test/gt/69_gt.bmp
# IOU: 0.0
# Processing test/image/70_sample.tiff & test/gt/70_gt.bmp
# IOU: 0.3713461964958971
# Processing test/image/71_sample.tiff & test/gt/71_gt.bmp
# IOU: 0.5278742310321257
# Processing test/image/72_sample.tiff & test/gt/72_gt.bmp
# IOU: 0.5421046507117645
# Processing test/image/73_sample.tiff & test/gt/73_gt.bmp
# IOU: 0.5841485822118488
# Processing test/image/74_sample.tiff & test/gt/74_gt.bmp
# IOU: 0.3308408996498724
# Processing test/image/75_sample.tiff & test/gt/75_gt.bmp
# IOU: 0.3916785061903795
# Processing test/image/76_sample.tiff & test/gt/76_gt.bmp
# IOU: 0.4620408457819153
# Processing test/image/77_sample.tiff & test/gt/77_gt.bmp
# IOU: 0.5305119107957426
# Processing test/image/78_sample.tiff & test/gt/78_gt.bmp
# IOU: 0.5266085254071371
# Processing test/image/79_sample.tiff & test/gt/79_gt.bmp
# IOU: 0.5184539966778755
# Processing test/image/80_sample.tiff & test/gt/80_gt.bmp
# IOU: 0.40446776104247756
# Processing test/image/81_sample.tiff & test/gt/81_gt.bmp
# IOU: 0.41416975648862614
# Processing test/image/82_sample.tiff & test/gt/82_gt.bmp
# IOU: 0.38725056832533467
# Processing test/image/83_sample.tiff & test/gt/83_gt.bmp
# IOU: 0.20024796217651575
# Processing test/image/84_sample.tiff & test/gt/84_gt.bmp
# IOU: 0.35424640279056246
# Processing test/image/85_sample.tiff & test/gt/85_gt.bmp
# IOU: 0.28660287840561083
# Processing test/image/86_sample.tiff & test/gt/86_gt.bmp
# IOU: 0.2753160995009943
# Processing test/image/87_sample.tiff & test/gt/87_gt.bmp
# IOU: 0.2800031615554853
# Processing test/image/88_sample.tiff & test/gt/88_gt.bmp
# IOU: 0.28612032212221694
# Processing test/image/89_sample.tiff & test/gt/89_gt.bmp
# IOU: 0.2792168674698795
# Processing test/image/90_sample.tiff & test/gt/90_gt.bmp
# IOU: 0.22680048416380877
# Processing test/image/91_sample.tiff & test/gt/91_gt.bmp
# IOU: 0.4774665042630938
# Processing test/image/92_sample.tiff & test/gt/92_gt.bmp
# IOU: 0.35046506711764086
# Processing test/image/93_sample.tiff & test/gt/93_gt.bmp
# IOU: 0.391541368875911
# Processing test/image/94_sample.tiff & test/gt/94_gt.bmp
# IOU: 0.26404535037993004
# Processing test/image/95_sample.tiff & test/gt/95_gt.bmp
# IOU: 0.3654734920961997
# Processing test/image/96_sample.tiff & test/gt/96_gt.bmp
# IOU: 0.36025036130238886
# Processing test/image/97_sample.tiff & test/gt/97_gt.bmp
# IOU: 0.33614328036628066
# Processing test/image/98_sample.tiff & test/gt/98_gt.bmp
# IOU: 0.24585125998770743
# Processing test/image/99_sample.tiff & test/gt/99_gt.bmp
# IOU: 0.2124604586793199
# Processing test/image/100_sample.tiff & test/gt/100_gt.bmp
# IOU: 0.30128218536258866
# Processing test/image/101_sample.tiff & test/gt/101_gt.bmp
# IOU: 0.38758995825265535
# Processing test/image/102_sample.tiff & test/gt/102_gt.bmp
# IOU: 0.27502632852304104
# Processing test/image/103_sample.tiff & test/gt/103_gt.bmp
# IOU: 0.2874037693779472
# Processing test/image/104_sample.tiff & test/gt/104_gt.bmp
# IOU: 0.0
# Processing test/image/105_sample.tiff & test/gt/105_gt.bmp
# IOU: 0.3695106098073521
# Processing test/image/106_sample.tiff & test/gt/106_gt.bmp
# IOU: 0.39021893130086766
# Processing test/image/107_sample.tiff & test/gt/107_gt.bmp
# IOU: 0.3837753642204708
# Processing test/image/108_sample.tiff & test/gt/108_gt.bmp
# IOU: 0.3807327199009444
# Processing test/image/109_sample.tiff & test/gt/109_gt.bmp
# IOU: 0.3580146460537022
# Processing test/image/110_sample.tiff & test/gt/110_gt.bmp
# IOU: 0.14841472845160908
# Processing test/image/111_sample.tiff & test/gt/111_gt.bmp
# IOU: 0.34654525181193085
# Processing test/image/112_sample.tiff & test/gt/112_gt.bmp
# IOU: 0.6861682127988297
# Processing test/image/113_sample.tiff & test/gt/113_gt.bmp
# IOU: 0.6317768336099271
# Processing test/image/114_sample.tiff & test/gt/114_gt.bmp
# IOU: 0.5217025225101382
# Processing test/image/115_sample.tiff & test/gt/115_gt.bmp
# IOU: 0.42554217642235903
# Processing test/image/116_sample.tiff & test/gt/116_gt.bmp
# IOU: 0.3608737237459078
# Processing test/image/117_sample.tiff & test/gt/117_gt.bmp
# IOU: 0.0
# Processing test/image/118_sample.tiff & test/gt/118_gt.bmp
# IOU: 0.3668776027731894
# Processing test/image/119_sample.tiff & test/gt/119_gt.bmp
# IOU: 0.6948739600492808
# Processing test/image/120_sample.tiff & test/gt/120_gt.bmp
# IOU: 0.3087000879507476
# Processing test/image/121_sample.tiff & test/gt/121_gt.bmp
# IOU: 0.00796931542496239
# Processing test/image/122_sample.tiff & test/gt/122_gt.bmp
# IOU: 0.4397538360792368
# Processing test/image/123_sample.tiff & test/gt/123_gt.bmp
# IOU: 0.0
# Processing test/image/124_sample.tiff & test/gt/124_gt.bmp
# IOU: 0.39244076049319254
# Processing test/image/125_sample.tiff & test/gt/125_gt.bmp
# IOU: 0.07357703669768251
# Processing test/image/126_sample.tiff & test/gt/126_gt.bmp
# IOU: 0.5346554008557962
# Processing test/image/127_sample.tiff & test/gt/127_gt.bmp
# IOU: 0.18658837492582067
# Processing test/image/128_sample.tiff & test/gt/128_gt.bmp
# IOU: 0.4590727117194183
# Processing test/image/129_sample.tiff & test/gt/129_gt.bmp
# IOU: 0.8340514611921993
# Processing test/image/130_sample.tiff & test/gt/130_gt.bmp
# IOU: 0.2949570918908495
# Processing test/image/131_sample.tiff & test/gt/131_gt.bmp
# IOU: 0.6432565405795155
# Processing test/image/132_sample.tiff & test/gt/132_gt.bmp
# IOU: 0.05745787908820615
# Processing test/image/133_sample.tiff & test/gt/133_gt.bmp
# IOU: 0.40186090671730357
# Processing test/image/134_sample.tiff & test/gt/134_gt.bmp
# IOU: 0.6116255847673242
# Processing test/image/135_sample.tiff & test/gt/135_gt.bmp
# IOU: 0.49647725758943767
# Processing test/image/136_sample.tiff & test/gt/136_gt.bmp
# IOU: 0.3928932886330571
# Processing test/image/137_sample.tiff & test/gt/137_gt.bmp
# IOU: 0.3992600881039506
# Processing test/image/138_sample.tiff & test/gt/138_gt.bmp
# IOU: 0.3767926720194097
# Processing test/image/139_sample.tiff & test/gt/139_gt.bmp
# IOU: 0.1772503311258278
# Processing test/image/140_sample.tiff & test/gt/140_gt.bmp
# IOU: 0.44942477725053764
# Processing test/image/141_sample.tiff & test/gt/141_gt.bmp
# IOU: 0.4765958543436617
# Processing test/image/142_sample.tiff & test/gt/142_gt.bmp
# IOU: 0.44382486575795127
# Processing test/image/143_sample.tiff & test/gt/143_gt.bmp
# IOU: 0.5972657074913004
# Processing test/image/144_sample.tiff & test/gt/144_gt.bmp
# IOU: 0.40528909403081587
# Processing test/image/145_sample.tiff & test/gt/145_gt.bmp
# IOU: 0.2880030485279255
# Processing test/image/146_sample.tiff & test/gt/146_gt.bmp
# IOU: 0.10547093146411446
# Processing test/image/147_sample.tiff & test/gt/147_gt.bmp
# IOU: 0.20589910870164477
# Processing test/image/148_sample.tiff & test/gt/148_gt.bmp
# IOU: 0.3478268455673233
# Processing test/image/149_sample.tiff & test/gt/149_gt.bmp
# IOU: 0.2196089778034969
# Processing test/image/150_sample.tiff & test/gt/150_gt.bmp
# IOU: 0.4335295628958568
# Processing test/image/151_sample.tiff & test/gt/151_gt.bmp
# IOU: 0.3343500293888704
# Processing test/image/152_sample.tiff & test/gt/152_gt.bmp
# IOU: 0.45528276299336023
# Processing test/image/153_sample.tiff & test/gt/153_gt.bmp
# IOU: 0.33416809838579736
# Processing test/image/154_sample.tiff & test/gt/154_gt.bmp
# IOU: 0.3765620445049072
# Processing test/image/155_sample.tiff & test/gt/155_gt.bmp
# IOU: 0.40359637151802197
# Processing test/image/156_sample.tiff & test/gt/156_gt.bmp
# IOU: 0.2532425757984519
# Processing test/image/157_sample.tiff & test/gt/157_gt.bmp
# IOU: 0.3199827777833405
# Processing test/image/158_sample.tiff & test/gt/158_gt.bmp
# IOU: 0.20252269244371096
# Processing test/image/159_sample.tiff & test/gt/159_gt.bmp
# IOU: 0.4058452434122376
# Processing test/image/160_sample.tiff & test/gt/160_gt.bmp
# IOU: 0.2402562207440256
# Processing test/image/161_sample.tiff & test/gt/161_gt.bmp
# IOU: 0.351597917949292
# Processing test/image/162_sample.tiff & test/gt/162_gt.bmp
# IOU: 0.5857683198416346
# Processing test/image/163_sample.tiff & test/gt/163_gt.bmp
# IOU: 0.36932797242963816
# Completed processing all images
# ----------Total Time Taken: 66.25592369238535 minutes-----------

# %%
im = skimage.io.imread("Output_Images/01_1.png")
plt.figure(figsize=(5,5))
plt.imshow(im)
plt.title('Output Image')
plt.show()

# %%
np.mean(np.array(iou_list))
# Out:
# 0.37643316511373487

# %%
len(iou_list)
# Out:
# 163

# %%
image_path = "training/image/1_sample.tiff"
ref_path = "BM_GRAZ_HE_0007_01.png"
output_path = "Output_Images/"
gt_path = "training/gt/1_gt.bmp"

iou = segment(image_path, ref_path, output_path, gt_path)

print(iou)
# Out:
# 0.46864086592464005
